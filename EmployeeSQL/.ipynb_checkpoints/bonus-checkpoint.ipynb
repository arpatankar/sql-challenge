# %%
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine, inspect
engine = create_engine('postgresql://localhost:5432/Homework SQL Challenge')
connection = engine.connect()

# MatPlotLib/NumPy/SciPy
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
employees = pd.read_sql("SELECT * FROM Employees", connection)
employees
# Out:
#         emp_no  emp_title_id  birth_date   first_name  last_name  sex  \
# 0       emp_no  emp_title_id  birth_date   first_name  last_name  sex
# 1       473302         s0001   7/25/1953     Hideyuki   Zallocco    M
# 2       475053         e0002  11/18/1954        Byong  Delgrande    F
# 3        57444         e0002   1/30/1958        Berry       Babb    F
# 4       421786         s0001   9/28/1957        Xiong   Verhoeff    M
# ...        ...           ...         ...          ...        ...  ...
# 300020  464231         s0001   8/14/1958  Constantino    Eastman    M
# 300021  255832         e0002    5/8/1955       Yuping     Dayang    F
# 300022   76671         s0001    6/9/1959       Ortrud   Plessier    M
# 300023  264920         s0001   9/22/1959        Percy   Samarati    F
# 300024  464503         s0002   5/31/1964       Arvind  Slobodova    M
#
#          hire_date
# 0        hire_date
# 1        4/28/1990
# 2         9/7/1991
# 3        3/21/1992
# 4       11/26/1987
# ...

# %%
clean_data = employees.drop([0], axis=0)
clean_data
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 1       473302        s0001   7/25/1953     Hideyuki   Zallocco   M
# 2       475053        e0002  11/18/1954        Byong  Delgrande   F
# 3        57444        e0002   1/30/1958        Berry       Babb   F
# 4       421786        s0001   9/28/1957        Xiong   Verhoeff   M
# 5       282238        e0003  10/28/1952   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300020  464231        s0001   8/14/1958  Constantino    Eastman   M
# 300021  255832        e0002    5/8/1955       Yuping     Dayang   F
# 300022   76671        s0001    6/9/1959       Ortrud   Plessier   M
# 300023  264920        s0001   9/22/1959        Percy   Samarati   F
# 300024  464503        s0002   5/31/1964       Arvind  Slobodova   M
#
#          hire_date
# 1        4/28/1990
# 2         9/7/1991
# 3        3/21/1992
# 4       11/26/1987
# 5        1/18/1991
# ...            ...
# ...

# %%
salaries = pd.read_sql("SELECT * FROM Salaries", connection)
salaries
# Out:
#         emp_no  salary
# 0       emp_no  salary
# 1        10001   60117
# 2        10002   65828
# 3        10003   40006
# 4        10004   40054
# ...        ...     ...
# 300020  499995   40000
# 300021  499996   58058
# 300022  499997   49597
# 300023  499998   40000
# 300024  499999   63707
#
# [300025 rows x 2 columns]

# %%
clean_data2 = salaries.drop([0], axis=0)
clean_data2
# Out:
#         emp_no salary
# 1        10001  60117
# 2        10002  65828
# 3        10003  40006
# 4        10004  40054
# 5        10005  78228
# ...        ...    ...
# 300020  499995  40000
# 300021  499996  58058
# 300022  499997  49597
# 300023  499998  40000
# 300024  499999  63707
#
# [300024 rows x 2 columns]

# %%
title = pd.read_sql("SELECT * FROM Titles", connection)
title
# Out:
#       title_id               title
# 0  ï»¿title_id               title
# 1        s0001               Staff
# 2        s0002        Senior Staff
# 3        e0001  Assistant Engineer
# 4        e0002            Engineer
# 5        e0003     Senior Engineer
# 6        e0004    Technique Leader
# 7        m0001             Manager

# %%
clean_data3 = title.drop([0], axis=0)
clean_data3
# Out:
#   title_id               title
# 1    s0001               Staff
# 2    s0002        Senior Staff
# 3    e0001  Assistant Engineer
# 4    e0002            Engineer
# 5    e0003     Senior Engineer
# 6    e0004    Technique Leader
# 7    m0001             Manager

# %%
df_1 = clean_data2.loc[:, ["salary"]]
df_1
# Out:
#        salary
# 1       60117
# 2       65828
# 3       40006
# 4       40054
# 5       78228
# ...       ...
# 300020  40000
# 300021  58058
# 300022  49597
# 300023  40000
# 300024  63707
#
# [300024 rows x 1 columns]

# %%
s=pd.DataFrame(df_1)
s.head()
# Out:
#   salary
# 1  60117
# 2  65828
# 3  40006
# 4  40054
# 5  78228

# %%
salary_df= clean_data2.groupby('salary').count()
print(salary_df)
# Out:
#         emp_no
# salary
# 100000       1
# 100006       1
# 100022       1
# 100025       1
# 100026       1
# ...        ...
# 99984        1
# 99988        1
# 99990        1
# 99993        1
# 99999        1
#
# [50355 rows x 1 columns]

# %%
csv="gt-atl-data-pt-06-2020-u-c/DataViz-Content/09-SQL/Homework/instructions/data/employees.csv"
csv2="gt-atl-data-pt-06-2020-u-c/DataViz-Content/09-SQL/Homework/instructions/data/salaries.csv"
csv3="gt-atl-data-pt-06-2020-u-c/DataViz-Content/09-SQL/Homework/instructions/data/titles.csv"

# %%
readcsv=pd.read_csv(csv)
readcsv.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001   7/25/1953    Hideyuki   Zallocco   M   4/28/1990
# 1  475053        e0002  11/18/1954       Byong  Delgrande   F    9/7/1991
# 2   57444        e0002   1/30/1958       Berry       Babb   F   3/21/1992
# 3  421786        s0001   9/28/1957       Xiong   Verhoeff   M  11/26/1987
# 4  282238        e0003  10/28/1952  Abdelkader    Baumann   F   1/18/1991

# %%
readcsv2=pd.read_csv(csv2)
readcsv2.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
readcsv3=pd.read_csv(csv3)
readcsv3.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
dfsalary = readcsv2.loc[:, ['salary']].count
r=pd.DataFrame(readcsv2)
r.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
r.hist(column='salary')
plt.xlabel("salary")
plt.ylabel("count")
plt.title ("Employee Salary Range")
plt.show()
